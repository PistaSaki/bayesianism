# %% [markdown]
# This notebook is a slightly modified version of:
# https://tiao.io/post/tutorial-on-variational-autoencoders-with-a-concise-keras-implementation/

# %% [markdown]
# #### Config

# %%
intermediate_dim = 256
latent_dim = 2
batch_size = 100
epochs = 50
epsilon_std = 1.0

# possible  `data_type` values: "random_circles", "MNIST"
data_type = "MNIST"

# %% [markdown]
# ## Imports and Setup

# %% [markdown]
# #### Preamble

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

from keras import backend as K

import keras.layers as kl
import keras
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd

from matplotlib.ticker import FormatStrFormatter
from keras.utils.vis_utils import model_to_dot, plot_model
from IPython.display import SVG

# %% [markdown]
# #### Notebook Configuration

# %%
np.set_printoptions(precision=2,
                    edgeitems=3,
                    linewidth=80,
                    suppress=True)

# %%
'TensorFlow version: ' + K.tf.__version__
# Out:
# 'TensorFlow version: 1.11.0'

# %% [markdown]
# ## Data

# %% [markdown]
# #### Random Circles

# %%
import cv2
import numpy.random as rnd

# %%
rnd.randint(0, 100)
# Out:
# 34

# %%
def generate_image(img_size = (100, 150)):
    img = np.zeros(img_size + (3,))
    
    x = rnd.randint(0, img_size[1])
    y = rnd.randint(0, img_size[0])

    cv2.circle(img,(x,y), 10, (0,0,255), -1)
    
    return img/255

# %%
img = generate_image()
plt.imshow(img)

# %%
if data_type == "random_circles":
    x_train = np.array([generate_image() for i in range(60000)])
    print(x_train.shape)
    x_test = np.array([generate_image() for i in range(10000)])
    print(x_test.shape)

# %% [markdown]
# #### MNIST

# %%
from keras.datasets import mnist

# %%
if data_type == "MNIST":
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train = np.expand_dims(x_train, axis=-1) / 255.
    x_test = np.expand_dims(x_test, axis=-1) / 255.
    
    print(x_train.shape)
    print(x_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %% [markdown]
# ## Model specification

# %% [markdown]
# ##### Constant definitions

# %%
input_shape = img_rows, img_cols, img_chns = x_train.shape[1:]
input_shape
# Out:
# (28, 28, 1)

# %%
original_dim = np.prod(input_shape)

# %% [markdown]
# ### Encoder

# %% [markdown]
# #### Inference network

# %%
x = kl.Input(shape=input_shape, name='x')
x_flat = kl.Flatten()(x)
h = kl.Dense(intermediate_dim, activation='relu', 
          name='hidden_enc')(x_flat)
z_mu = kl.Dense(latent_dim, name='mu')(h)
z_log_var = kl.Dense(latent_dim, name='log_var')(h)
z_sigma = kl.Lambda(lambda t: K.exp(.5*t), name='sigma')(z_log_var)

# %%
infer = keras.Model(inputs=x, outputs=[z_mu, z_sigma], name = "infer")

# %%
SVG(model_to_dot(infer, show_shapes=False)
    .create(prog='dot', format='svg'))

# %%
infer.output
# Out:
# [<tf.Tensor 'mu/BiasAdd:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'sigma/Exp:0' shape=(?, 2) dtype=float32>]

# %% [markdown]
# ### Decoder

# %%
decoder = keras.Sequential([
    kl.InputLayer(input_shape=(latent_dim,), name='z'),
    kl.Dense(intermediate_dim, input_shape=(latent_dim,),
          activation='relu', name='hidden_dec'),
    kl.Dense(original_dim, activation='sigmoid', name='x_pred'),
    kl.Reshape(input_shape)
], name='decoder')

# %%
SVG(model_to_dot(decoder, show_shapes=False)
    .create(prog='dot', format='svg'))

# %% [markdown]
# ### Specifying the VAE

# %%
from vae_tools import get_vae

# %%
vae = get_vae(inferer = infer, decoder = decoder)

# %%
def nll(y_true, y_pred):
    """ Negative log likelihood (Bernoulli). """

    # keras.losses.binary_crossentropy gives the mean
    # over the image pixels. we require the sum
    return K.sum(K.binary_crossentropy(y_true, y_pred), axis=(-1, -2, -3))

# %%
vae.compile(optimizer='rmsprop', loss=nll)

# %%
vae.predict(x_train).shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# ## Model fitting

# %%
hist = vae.fit(
    x_train,
    x_train,
    shuffle=True,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(x_test, x_test)
)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 38us/step - loss: 188.7369 - val_loss: 171.4219
# Epoch 2/50
# 60000/60000 [==============================] - 2s 35us/step - loss: 168.8352 - val_loss: 167.1234
# Epoch 3/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 165.6382 - val_loss: 164.6411
# Epoch 4/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 163.5101 - val_loss: 162.8619
# Epoch 5/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 161.7636 - val_loss: 161.1212
# Epoch 6/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 160.3113 - val_loss: 159.8604
# Epoch 7/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 159.1682 - val_loss: 158.9321
# Epoch 8/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 158.2329 - val_loss: 158.1245
# Epoch 9/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 157.5003 - val_loss: 157.5163
# Epoch 10/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 156.8683 - val_loss: 157.2183
# Epoch 11/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 156.3539 - val_loss: 156.3121
# Epoch 12/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 155.8709 - val_loss: 156.0935
# Epoch 13/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 155.4584 - val_loss: 155.7565
# Epoch 14/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 155.0800 - val_loss: 155.3527
# Epoch 15/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 154.7442 - val_loss: 155.0697
# Epoch 16/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 154.4564 - val_loss: 155.0492
# Epoch 17/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 154.1545 - val_loss: 154.6015
# Epoch 18/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 153.8879 - val_loss: 154.7831
# Epoch 19/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 153.6289 - val_loss: 154.7011
# Epoch 20/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 153.4268 - val_loss: 153.9326
# Epoch 21/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 153.2159 - val_loss: 154.1283
# Epoch 22/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 153.0170 - val_loss: 153.7396
# Epoch 23/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 152.8022 - val_loss: 153.9778
# Epoch 24/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 152.6177 - val_loss: 153.5661
# Epoch 25/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 152.4378 - val_loss: 153.3294
# Epoch 26/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 152.2933 - val_loss: 153.7185
# Epoch 27/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 152.1026 - val_loss: 153.3807
# Epoch 28/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 151.9758 - val_loss: 153.4079
# Epoch 29/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 151.8128 - val_loss: 153.3748
# Epoch 30/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 151.6824 - val_loss: 152.8100
# Epoch 31/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 151.5335 - val_loss: 152.6326
# Epoch 32/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 151.3992 - val_loss: 152.4983
# Epoch 33/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 151.2826 - val_loss: 152.5456
# Epoch 34/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 151.1487 - val_loss: 153.1002
# Epoch 35/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 151.0084 - val_loss: 152.7889
# Epoch 36/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 150.9026 - val_loss: 152.6190
# Epoch 37/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 150.8021 - val_loss: 152.4444
# Epoch 38/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 150.6488 - val_loss: 152.4296
# Epoch 39/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 150.5522 - val_loss: 152.1499
# Epoch 40/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 150.4469 - val_loss: 152.0114
# Epoch 41/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 150.3433 - val_loss: 151.9437
# Epoch 42/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 150.2465 - val_loss: 152.2100
# Epoch 43/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 150.1334 - val_loss: 151.7051
# Epoch 44/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 150.0261 - val_loss: 152.0528
# Epoch 45/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 149.9068 - val_loss: 151.8145
# Epoch 46/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 149.8744 - val_loss: 151.5579
# Epoch 47/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 149.7421 - val_loss: 151.6283
# Epoch 48/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 149.6506 - val_loss: 151.7290
# Epoch 49/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 149.6006 - val_loss: 151.9345
# Epoch 50/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 149.4868 - val_loss: 151.9330

# %% [markdown]
# ## Model Evaluation

# %%
golden_size = lambda width: (width, 2. * width / (1 + np.sqrt(5)))

# %% [markdown]
# ### NELBO

# %%
fig, ax = plt.subplots(figsize=golden_size(6))

hist_df = pd.DataFrame(hist.history)
hist_df.plot(ax=ax)

ax.set_ylabel('NELBO')
ax.set_xlabel('# epochs')

ax.set_ylim(.99*hist_df[1:].values.min(), 
            1.1*hist_df[1:].values.max())

#plt.savefig('../../images/vae/nelbo.svg', format='svg')
#plt.show()
# Out:
# (147.99188524932862, 185.7187675755819)

# %% [markdown]
# ### Observed space manifold

# %%
# display a 2D manifold of the images
n = 15  # figure with 15x15 images
quantile_min = 0.01
quantile_max = 0.99

# linearly spaced coordinates on the unit square were transformed
# through the inverse CDF (ppf) of the Gaussian to produce values
# of the latent variables z, since the prior of the latent space
# is Gaussian

z1 = norm.ppf(np.linspace(quantile_min, quantile_max, n))
z2 = norm.ppf(np.linspace(quantile_max, quantile_min, n))
z_grid = np.dstack(np.meshgrid(z1, z2))

# %%
x_pred_grid = decoder.predict(z_grid.reshape(n*n, latent_dim)) \
                     .reshape((n, n)+ input_shape)

# %%
def stack_image_grid(img_grid):
    return np.block(
        list(map(list, np.transpose(img_grid, (0, 1, 4, 2, 3))))
    ).transpose(1, 2, 0)

# %%
stacked_x_pred_grid = stack_image_grid(x_pred_grid)
# if img_chns == 1:
#     stacked_x_pred_grid =

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.imshow(np.squeeze(stack_image_grid(x_pred_grid)))

ax.set_xticks(np.arange(0, n*img_rows, img_rows) + .5 * img_rows)
ax.set_xticklabels(map('{:.2f}'.format, z1), rotation=90)

ax.set_yticks(np.arange(0, n*img_cols, img_cols) + .5 * img_cols)
ax.set_yticklabels(map('{:.2f}'.format, z2))

ax.set_xlabel('$z_1$')
ax.set_ylabel('$z_2$')

# plt.savefig('../../images/vae/result_manifold.png')
# plt.show()
# Out:
# Text(0, 0.5, '$z_2$')

# %%
norm.ppf(quantile_min), norm.ppf(quantile_max)
# Out:
# (-2.3263478740408408, 2.3263478740408408)

# %%
import ipywidgets as ipw

# %%
def plot_decoded(q1, q2):
    z1 = norm.ppf(q1)
    z2 = norm.ppf(q2)
    
    plt.imshow(decoder.predict(np.array([[z1, z2]])).squeeze())

ipw.interact(
    plot_decoded,
    q1 = ipw.FloatSlider(min = quantile_min, max = quantile_max, step = 0.01),
    q2 = ipw.FloatSlider(min = quantile_min, max = quantile_max, step = 0.01),
)
# Out:
# interactive(children=(FloatSlider(value=0.01, description='q1', max=0.99, min=0.01, step=0.01), FloatSlider(va…
# <function __main__.plot_decoded(q1, q2)>

# %% [markdown]
# #### Following works for MNIST only

# %%
# display a 2D plot of the digit classes in the latent space
if data_type == "MNIST":
    z_test_mu, z_test_sigma = infer.predict(x_test, batch_size=batch_size)

    fig, ax = plt.subplots(figsize=(6, 5))

    cbar = ax.scatter(z_test_mu[:, 0], z_test_mu[:, 1], c=y_test,
                       alpha=.4, s=3**2, cmap='viridis')
    fig.colorbar(cbar, ax=ax)

    ax.set_xlim(2.*norm.ppf((quantile_min, quantile_max)))
    ax.set_ylim(2.*norm.ppf((quantile_min, quantile_max)))

    ax.set_xlabel('$z_1$')
    ax.set_ylabel('$z_2$')
