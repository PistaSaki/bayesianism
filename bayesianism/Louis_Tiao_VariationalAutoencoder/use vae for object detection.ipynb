# %% [markdown]
# This notebook is a slightly modified version of:
# https://tiao.io/post/tutorial-on-variational-autoencoders-with-a-concise-keras-implementation/

# %% [markdown]
# #### Config

# %%
intermediate_dim = 256
latent_dim = 2
batch_size = 100
epochs = 50
epsilon_std = 1.0

# possible  `data_type` values: "random_circles", "MNIST"
data_type = "random_circles"

# %% [markdown]
# ## Imports and Setup

# %% [markdown]
# #### Preamble

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

from keras import backend as K

import keras.layers as kl
import keras
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd

from matplotlib.ticker import FormatStrFormatter
from keras.utils.vis_utils import model_to_dot, plot_model
from IPython.display import SVG

# %% [markdown]
# #### Notebook Configuration

# %%
np.set_printoptions(precision=2,
                    edgeitems=3,
                    linewidth=80,
                    suppress=True)

# %%
'TensorFlow version: ' + K.tf.__version__
# Out:
# 'TensorFlow version: 1.11.0'

# %% [markdown]
# ## Data

# %% [markdown]
# #### Random Circles

# %%
import cv2
import numpy.random as rnd

# %%
rnd.randint(0, 100)
# Out:
# 85

# %%
def generate_image(img_size = (128, 128)):
    img = np.zeros(img_size + (3,))
    
    x = rnd.randint(0, img_size[1])
    y = rnd.randint(0, img_size[0])

    cv2.circle(img,(x,y), 10, (0,0,255), -1)
    
    return img/255

# %%
img = generate_image()
plt.imshow(img)

# %%
if data_type == "random_circles":
    x_train = np.array([generate_image() for i in range(60000)])
    print(x_train.shape)
    x_test = np.array([generate_image() for i in range(10000)])
    print(x_test.shape)
# Out:
# (60000, 128, 128, 3)
# (10000, 128, 128, 3)

# %% [markdown]
# #### MNIST

# %%
from keras.datasets import mnist

# %%
if data_type == "MNIST":
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train = np.expand_dims(x_train, axis=-1) / 255.
    x_test = np.expand_dims(x_test, axis=-1) / 255.
    
    print(x_train.shape)
    print(x_test.shape)

# %% [markdown]
# ## Model specification

# %% [markdown]
# ##### Constant definitions

# %%
input_shape = img_rows, img_cols, img_chns = x_train.shape[1:]
input_shape
# Out:
# (128, 128, 3)

# %%
original_dim = np.prod(input_shape)

# %% [markdown]
# ### Encoder

# %% [markdown]
# #### Inference network

# %%
conv_shapes = []
def add_conv_shape(x):
    conv_shapes.append([int(d) for d in x.shape[1:]])


x = inp = kl.Input(shape=input_shape, name='x')
add_conv_shape(x)

x = kl.Convolution2D(4, kernel_size=[3, 3], padding = "same")(x)
x= kl.MaxPooling2D([2, 2])(x)
add_conv_shape(x)

x = kl.Convolution2D(4, kernel_size=[3, 3], padding = "same")(x)
x= kl.MaxPooling2D([2, 2])(x)
add_conv_shape(x)

x_flat = kl.Flatten()(x)
h = kl.Dense(intermediate_dim, activation='relu', 
          name='hidden_enc')(x_flat)
z_mu = kl.Dense(latent_dim, name='mu')(h)
z_log_var = kl.Dense(latent_dim, name='log_var')(h)
z_sigma = kl.Lambda(lambda t: K.exp(.5*t), name='sigma')(z_log_var)

# %%
infer = keras.Model(inputs=inp, outputs=[z_mu, z_sigma], name = "infer")

# %%
SVG(model_to_dot(infer, show_shapes=True)
    .create(prog='dot', format='svg'))

# %%
conv_shapes
# Out:
# [[128, 128, 3], [64, 64, 4], [32, 32, 4]]

# %%
a = kl.Input([10, 10, 3])

# %%
a
# Out:
# <tf.Tensor 'input_1:0' shape=(?, 10, 10, 3) dtype=float32>

# %%
b = kl.Deconv2D(3, [3, 3], padding = "same", strides=[2, 2])(a)

# %%
b
# Out:
# <tf.Tensor 'conv2d_transpose_1/BiasAdd:0' shape=(?, ?, ?, 3) dtype=float32>

# %%
m = keras.Model(inputs = a, outputs = b)

# %%
m.predict(np.zeros([1, 10, 10, 3])).shape
# Out:
# (1, 20, 20, 3)

# %% [markdown]
# ### Decoder

# %%
infer.input
# Out:
# <tf.Tensor 'x:0' shape=(?, 128, 128, 3) dtype=float32>

# %%
infer.output
# Out:
# [<tf.Tensor 'mu/BiasAdd:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'sigma/Exp:0' shape=(?, 2) dtype=float32>]

# %%
decoder = keras.Sequential([
    kl.InputLayer(input_shape=(latent_dim,), name='z'),
    kl.Dense(intermediate_dim, input_shape=(latent_dim,),
          activation='relu', name='hidden_dec'),
    kl.Dense(np.prod(conv_shapes[-1]), activation='sigmoid', name='x_pred'),
    kl.Reshape(conv_shapes[-1]),
    
    kl.Deconv2D(filters = 3, kernel_size=[3, 3], strides = [2, 2], padding = "same"),
    kl.Deconv2D(filters = 3, kernel_size=[3, 3], strides = [2, 2], padding = "same"),
], name='decoder')

# %%
SVG(model_to_dot(decoder, show_shapes=True)
    .create(prog='dot', format='svg'))

# %% [markdown]
# ### Specifying the VAE

# %%
from vae_tools import get_vae

# %%
vae = get_vae(inferer = infer, decoder = decoder)

# %%
def nll(y_true, y_pred):
    """ Negative log likelihood (Bernoulli). """

    # keras.losses.binary_crossentropy gives the mean
    # over the image pixels. we require the sum
    return K.sum(K.binary_crossentropy(y_true, y_pred), axis=(-1, -2, -3))

# %%
vae.compile(optimizer='rmsprop', loss=nll)

# %%
vae.predict(x_train).shape
# Out:
# (60000, 128, 128, 3)

# %% [markdown]
# ## Model fitting

# %%
hist = vae.fit(
    x_train,
    x_train,
    shuffle=True,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(x_test, x_test)
)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 180.8232 - val_loss: 172.4915
# Epoch 2/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 181.4887 - val_loss: 142.4525
# Epoch 3/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 175.6506 - val_loss: 145.1740
# Epoch 4/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 173.4572 - val_loss: 157.4737
# Epoch 5/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 174.8562 - val_loss: 149.2976
# Epoch 6/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 183.2231 - val_loss: 144.6729
# Epoch 7/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 187.2301 - val_loss: 162.5312
# Epoch 8/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 176.6497 - val_loss: 550.6870
# Epoch 9/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 168.3458 - val_loss: 139.6468
# Epoch 10/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 172.9615 - val_loss: 194.9722
# Epoch 11/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 173.5655 - val_loss: 139.2291
# Epoch 12/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 174.9104 - val_loss: 156.9278
# Epoch 13/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 179.3259 - val_loss: 139.0136
# Epoch 14/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 189.4625 - val_loss: 193.7943
# Epoch 15/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 170.9894 - val_loss: 162.4903
# Epoch 16/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 165.0054 - val_loss: 137.0798
# Epoch 17/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 169.9845 - val_loss: 277.2321
# Epoch 18/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 164.7601 - val_loss: 150.0360
# Epoch 19/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 174.0224 - val_loss: 159.1279
# Epoch 20/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 168.2571 - val_loss: 181.9928
# Epoch 21/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 172.3527 - val_loss: 138.1246
# Epoch 22/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 164.9671 - val_loss: 130.9490
# Epoch 23/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 163.4777 - val_loss: 270.5552
# Epoch 24/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 170.0456 - val_loss: 129.5124
# Epoch 25/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 166.8009 - val_loss: 160.8340
# Epoch 26/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 176.7517 - val_loss: 189.5882
# Epoch 27/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 169.9328 - val_loss: 128.8145
# Epoch 28/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 175.1945 - val_loss: 148.2382
# Epoch 29/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 173.7019 - val_loss: 137.0899
# Epoch 30/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 171.3207 - val_loss: 139.5177
# Epoch 31/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 169.1168 - val_loss: 143.2997
# Epoch 32/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 171.0437 - val_loss: 168.6377
# Epoch 33/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 175.1121 - val_loss: 144.7349
# Epoch 34/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 167.4212 - val_loss: 138.5908
# Epoch 35/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 173.9963 - val_loss: 130.7031
# Epoch 36/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 170.0488 - val_loss: 168.2818
# Epoch 37/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 165.9255 - val_loss: 127.7216
# Epoch 38/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 169.4519 - val_loss: 295.5650
# Epoch 39/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 179.1223 - val_loss: 131.8273
# Epoch 40/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 164.6707 - val_loss: 152.2359
# Epoch 41/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 172.4189 - val_loss: 147.3737
# Epoch 42/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 182.9618 - val_loss: 385.4774
# Epoch 43/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 167.6403 - val_loss: 137.7349
# Epoch 44/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 182.3018 - val_loss: 146.7213
# Epoch 45/50
# 60000/60000 [==============================] - 73s 1ms/step - loss: 170.5388 - val_loss: 159.7323
# Epoch 46/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 169.2254 - val_loss: 438.6423
# Epoch 47/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 165.4076 - val_loss: 129.8410
# Epoch 48/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 170.6245 - val_loss: 149.3037
# Epoch 49/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 169.6202 - val_loss: 130.9300
# Epoch 50/50
# 60000/60000 [==============================] - 72s 1ms/step - loss: 161.0356 - val_loss: 128.0914

# %% [markdown]
# ## Model Evaluation

# %%
golden_size = lambda width: (width, 2. * width / (1 + np.sqrt(5)))

# %% [markdown]
# ### NELBO

# %%
fig, ax = plt.subplots(figsize=golden_size(6))

hist_df = pd.DataFrame(hist.history)
hist_df.plot(ax=ax)

ax.set_ylabel('NELBO')
ax.set_xlabel('# epochs')

ax.set_ylim(.99*hist_df[1:].values.min(), 
            1.1*hist_df[1:].values.max())

#plt.savefig('../../images/vae/nelbo.svg', format='svg')
#plt.show()
# Out:
# (126.44439430847167, 605.7556873779297)

# %% [markdown]
# ### Observed space manifold

# %%
# display a 2D manifold of the images
n = 15  # figure with 15x15 images
quantile_min = 0.01
quantile_max = 0.99

# linearly spaced coordinates on the unit square were transformed
# through the inverse CDF (ppf) of the Gaussian to produce values
# of the latent variables z, since the prior of the latent space
# is Gaussian

z1 = norm.ppf(np.linspace(quantile_min, quantile_max, n))
z2 = norm.ppf(np.linspace(quantile_max, quantile_min, n))
z_grid = np.dstack(np.meshgrid(z1, z2))

# %%
x_pred_grid = decoder.predict(z_grid.reshape(n*n, latent_dim)) \
                     .reshape((n, n)+ input_shape)

# %%
def stack_image_grid(img_grid):
    return np.block(
        list(map(list, np.transpose(img_grid, (0, 1, 4, 2, 3))))
    ).transpose(1, 2, 0)

# %%
stacked_img = stack_image_grid(x_pred_grid)

# %%
for x in range(0, stacked_img.shape[1], img_cols):
    stacked_img[:, x] = 1/2
for y in range(0, stacked_img.shape[0], img_cols):
    stacked_img[y, :] = 1/2

# %%
fig, ax = plt.subplots(figsize=(50, 50))

ax.imshow(np.squeeze(stacked_img))

ax.set_xticks(np.arange(0, n*img_rows, img_rows) + .5 * img_rows)
ax.set_xticklabels(map('{:.2f}'.format, z1), rotation=90)

ax.set_yticks(np.arange(0, n*img_cols, img_cols) + .5 * img_cols)
ax.set_yticklabels(map('{:.2f}'.format, z2))

ax.set_xlabel('$z_1$')
ax.set_ylabel('$z_2$')

# plt.savefig('../../images/vae/result_manifold.png')
# plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0, 0.5, '$z_2$')

# %%
norm.ppf(quantile_min), norm.ppf(quantile_max)
# Out:
# (-2.3263478740408408, 2.3263478740408408)

# %%
import ipywidgets as ipw

# %%
def plot_decoded(q1, q2):
    z1 = norm.ppf(q1)
    z2 = norm.ppf(q2)
    
    plt.imshow(decoder.predict(np.array([[z1, z2]])).squeeze())

ipw.interact(
    plot_decoded,
    q1 = ipw.FloatSlider(min = quantile_min, max = quantile_max, step = 0.01),
    q2 = ipw.FloatSlider(min = quantile_min, max = quantile_max, step = 0.01),
)
# Out:
# interactive(children=(FloatSlider(value=0.01, description='q1', max=0.99, min=0.01, step=0.01), FloatSlider(va…
# <function __main__.plot_decoded(q1, q2)>

# %% [markdown]
# #### Following works for MNIST only

# %%
# display a 2D plot of the digit classes in the latent space
if data_type == "MNIST":
    z_test_mu, z_test_sigma = infer.predict(x_test, batch_size=batch_size)

    fig, ax = plt.subplots(figsize=(6, 5))

    cbar = ax.scatter(z_test_mu[:, 0], z_test_mu[:, 1], c=y_test,
                       alpha=.4, s=3**2, cmap='viridis')
    fig.colorbar(cbar, ax=ax)

    ax.set_xlim(2.*norm.ppf((quantile_min, quantile_max)))
    ax.set_ylim(2.*norm.ppf((quantile_min, quantile_max)))

    ax.set_xlabel('$z_1$')
    ax.set_ylabel('$z_2$')
